# %%
import tweepy
import random
from matplotlib import pyplot as plt

# %%
auth = tweepy.OAuth2AppHandler("MleJeiU9KM26evls623GTZUZu", "exhT0sUUmIJOlutw0hOmggdwooaW17KchsWCIw555bEHu5ZZtr")

# %%
# api = tweepy.API(auth)

# %%
# api.home_timeline()

# %%
client = tweepy.Client(bearer_token='AAAAAAAAAAAAAAAAAAAAANBeYAEAAAAAgveakwQF7x6LG1RisGOLsZE%2FxOg%3DQjd7wwADzri230cjA9ERzWVP2qPIrvbiuSMXu29igUyQaGsPh0')

# %%
import networkx as nx
# G = nx.Graph()
G = nx.DiGraph()

# %%
G.add_node(1)

# %%
G.add_nodes_from([2, 3])

# %%
G.add_edge(1, 2)

# %%
G.add_edges_from([(1, 2), (1, 3)])

# %%
for i in range(100):
    G.add_node(i)

for i in range(40):
    G.add_edge(random.randrange(0,100),random.randrange(0,100))

# %%
G.clear()

# %%
nx.draw(G, with_labels=True)

# %%
nx.draw_shell(G,nlist=[range(0,20),range(20,40),range(40,60),range(60,80),range(80,100)])

# %%
nx.draw_random(G)

# %%
nx.draw_random(G)

# %%
for i in range(99):
    G.add_edge(1,i+2)

# %%
options = {
     'node_color': 'black',
     'node_size': 100,
     'width': 1.5,
 }
nx.draw_random(G, **options)
# nx.draw_circular(G, **options)
# nx.draw_spectral(G, **options)
