# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import csv

# %%
politician=[]
with open("politician.csv","r") as f:
    csvreader = csv.reader(f)
    for row in csvreader:
        politician.append(row)

# %%
# politician

# for i in range(len(politician)):
#     print(politician[i][1])

# %%
politician_data={}

# %%
# for j in range(len(politician)):
#     tweets_list1 = []
#     for i,tweet in enumerate(sntwitter.TwitterSearchScraper(f'from:{politician[j][1]} since:2022-01-01 until:2022-03-10').get_items()):
#         if i>100:
#             break

#         tweets_list1.append([tweet.date, tweet.id, tweet.content])
#     # print(politician[j][1])
#     # print()
#     # print(tweets_list1)
#     # break
#     politician_data[politician[j][1]]=tweets_list1
#     if(j==4):
#         break

# %%
tweets_list1 = []
for j in range(len(politician)):
    
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(f'from:{politician[j][1]} since:2022-01-01 until:2022-03-10').get_items()):
        # if i>100:
        #     break

        tweets_list1.append([tweet.user.username,tweet.user.id,tweet.user.description,tweet.user.verified,tweet.user.followersCount,tweet.user.friendsCount,tweet.user.listedCount,tweet.user.location,politician[j][0],tweet.content,tweet.date, tweet.id,tweet.url,tweet.replyCount,tweet.retweetCount,tweet.likeCount,tweet.quoteCount ])
    
    # politician_data[politician[j][1]]=tweets_list1
    # break
    # if(j==4):
    #     break

# %%
len(tweets_list1)
# Out:
# 14584

# %%
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Username','Userid','Profile_Description','Verified?','Count_of_Followers','Count_of_Friends','Total_list_count','Location','Party','Tweet','Tweet_Datatime', 'Tweet_Id','Tweet_URL','Tweet_ReplyCount','Tweet_retweetCount','Tweet_LikeCount','Tweet_quoteCount'])

# %%
tweets_df1
# Out:
#               Username      Userid  \
# 0      myogiadityanath  3437532637
# 1      myogiadityanath  3437532637
# 2      myogiadityanath  3437532637
# 3      myogiadityanath  3437532637
# 4      myogiadityanath  3437532637
# ...                ...         ...
# 14579    UrsIncredibly  2258989082
# 14580    UrsIncredibly  2258989082
# 14581    UrsIncredibly  2258989082
# 14582    UrsIncredibly  2258989082
# 14583    UrsIncredibly  2258989082
#
#                                      Profile_Description  Verified  \
# 0      मुख्यमंत्री (उत्तर प्रदेश); गोरक्षपीठाधीश्वर, ...      True
# 1      मुख्यमंत्री (उत्तर प्रदेश); गोरक्षपीठाधीश्वर, ...      True
# 2      मुख्यमंत्री (उत्तर प्रदेश); गोरक्षपीठाधीश्वर, ...      True
# 3      मुख्यमंत्री (उत्तर प्रदेश); गोरक्षपीठाधीश्वर, ...      True
# 4      मुख्यमंत्री (उत्तर प्रदेश); गोरक्षपीठाधीश्वर, ...      True
# ...                                                  ...       ...
# 14579                                                 ✴️     False
# 14580                                                 ✴️     False
# 14581                                                 ✴️     False
# 14582                                                 ✴️     False
# 14583                                                 ✴️     False
#
#        Count_of_Followers  Count_of_Friends  Total_list_count  \
# 0                18383389                50              3088
# 1                18383389                50              3088
# 2                18383389                50              3088
# 3                18383389                50              3088
# 4                18383389                50              3088
# ...                   ...               ...               ...
# 14579                 112                77                 2
# 14580                 112                77                 2
# 14581                 112                77                 2
# 14582                 112                77                 2
# 14583                 112                77                 2
#
#                     Location  Party  \
# 0      गोरखपुर, उत्तर प्रदेश    bjp
# 1      गोरखपुर, उत्तर प्रदेश    bjp
# 2      गोरखपुर, उत्तर प्रदेश    bjp
# 3      गोरखपुर, उत्तर प्रदेश    bjp
# 4      गोरखपुर, उत्तर प्रदेश    bjp
# ...                      ...    ...
# 14579         Union of India  other
# 14580         Union of India  other
# 14581         Union of India  other
# 14582         Union of India  other
# 14583         Union of India  other
#
#                                                    Tweet  \
# 0      नारी सशक्तिकरण की अप्रतिम प्रतीक, महान समाज सु...
# 1      असम नगर निकाय चुनाव में @BJP4Assam को मिली प्र...
# 2      ये खिलखिलाहट, ये निश्छल स्नेह, ये निश्चिंतता औ...
# 3      यूक्रेन से सुरक्षित घर वापस आए विद्यार्थियों क...
# 4      याद रखना!\n\nकभी भी शॉर्टकट का रास्ता व्यक्ति ...
# ...                                                  ...
# 14579  @RagaTimes Sorry . For a moment i thought the ...
# 14580  @RagaTimes हिंदी में लाओ, और व्हाट्सएप फेसबुक ...
# 14581  @thispacino @INCIndia Happy bday . Keep fighti...
# 14582  @PPSbtp He is not committed. Confirm tab hua j...
# 14583  @AadeshRawal No thanks. Get lost. Only Congres...
#
#                  Tweet_Datatime             Tweet_Id  \
# 0     2022-03-09 23:38:00+00:00  1501703881075658757
# 1     2022-03-09 12:58:22+00:00  1501542912345075714
# 2     2022-03-09 10:58:34+00:00  1501512762727755776
# 3     2022-03-09 05:19:40+00:00  1501427477201453056
# 4     2022-03-08 12:10:49+00:00  1501168558201470982
# ...                         ...                  ...
# 14579 2021-12-12 05:04:57+00:00  1469896031387017217
# 14580 2021-12-12 00:10:19+00:00  1469821881674973185
# 14581 2021-12-11 16:55:52+00:00  1469712548446433280
# 14582 2021-12-11 16:44:05+00:00  1469709585325846529
# 14583 2021-12-09 17:31:49+00:00  1468996820764295168
#
#                                                Tweet_URL  Tweet_ReplyCount  \
# 0      https://twitter.com/myogiadityanath/status/150...              1852
# 1      https://twitter.com/myogiadityanath/status/150...              1272
# 2      https://twitter.com/myogiadityanath/status/150...              1381
# 3      https://twitter.com/myogiadityanath/status/150...               515
# 4      https://twitter.com/myogiadityanath/status/150...              3712
# ...                                                  ...               ...
# 14579  https://twitter.com/UrsIncredibly/status/14698...                 1
# 14580  https://twitter.com/UrsIncredibly/status/14698...                 1
# 14581  https://twitter.com/UrsIncredibly/status/14697...                 1
# 14582  https://twitter.com/UrsIncredibly/status/14697...                 0
# 14583  https://twitter.com/UrsIncredibly/status/14689...                 0
#
#        Tweet_retweetCount  Tweet_LikeCount  Tweet_quoteCount
# 0                    3906            34194               128
# 1                    4163            29531                77
# 2                    5537            33202               249
# 3                    2216            12834                45
# 4                    9127            67441               451
# ...                   ...              ...               ...
# 14579                   0                0                 0
# 14580                   0                0                 0
# 14581                   0                2                 0
# 14582                   0                1                 0
# 14583                   0                0                 0
#
# [14584 rows x 17 columns]

# %%
tweets_df1.to_csv('Aman_data3.csv',index=False)

# %%
# df = pd.read_csv('Aman_data.csv')

# %%
# Out:
#               Username  Party  \
# 0      myogiadityanath    bjp
# 1      myogiadityanath    bjp
# 2      myogiadityanath    bjp
# 3      myogiadityanath    bjp
# 4      myogiadityanath    bjp
# ...                ...    ...
# 10937    UrsIncredibly  other
# 10938    UrsIncredibly  other
# 10939    UrsIncredibly  other
# 10940    UrsIncredibly  other
# 10941    UrsIncredibly  other
#
#                                                    Tweet  \
# 0      नारी सशक्तिकरण की अप्रतिम प्रतीक, महान समाज सु...
# 1      असम नगर निकाय चुनाव में @BJP4Assam को मिली प्र...
# 2      ये खिलखिलाहट, ये निश्छल स्नेह, ये निश्चिंतता औ...
# 3      यूक्रेन से सुरक्षित घर वापस आए विद्यार्थियों क...
# 4      याद रखना!\n\nकभी भी शॉर्टकट का रास्ता व्यक्ति ...
# ...                                                  ...
# 10937                    @priyankagandhi Do a PC on NTPC
# 10938                    @TheTennisTalker Kenin vs keys.
# 10939  Never seen any SP guy praising cong. \nThey r ...
# 10940  कांग्रेस का campaign और candidates सबसे साफ सु...
# 10941  #LucknowPanchayatAajtak \n#SonuSoodWithCongres...
#
#                   Tweet_Datatime             Tweet_Id
# 0      2022-03-09 23:38:00+00:00  1501703881075658757
# 1      2022-03-09 12:58:22+00:00  1501542912345075714
# 2      2022-03-09 10:58:34+00:00  1501512762727755776
# 3      2022-03-09 05:19:40+00:00  1501427477201453056
# 4      2022-03-08 12:10:49+00:00  1501168558201470982
# ...                          ...                  ...
# 10937  2022-01-26 04:33:29+00:00  1486195565129912322
# 10938  2022-01-16 16:09:21+00:00  1482746804941000705
# 10939  2022-01-12 05:02:29+00:00  1481129431959674882
# 10940  2022-01-11 16:31:35+00:00  1480940463242629120
# 10941  2022-01-10 14:02:11+00:00  1480540475098427395
#
# [10942 rows x 5 columns]

# %%
# politician_data.keys()
# Out:
# dict_keys(['myogiadityanath', 'asim_arun', 'kpmaurya1', 'brajeshpathakup', 'AditiSinghRBL', 'ptshrikant'])

# %%
# Using TwitterSearchScraper to scrape data and append tweets to list


# for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:myogiadityanath since:2022-01-01 until:2022-03-10').get_items()):
#     # if i>100:
#     #     break
#     tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username])

# %%
# print(len(tweets_list1))
# Out:
# 2089

# %%
# Creating a dataframe from the tweets list above 
# tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])

# %%
# tweets_df1
# Out:
#                      Datetime             Tweet Id  \
# 0   2022-03-09 23:38:00+00:00  1501703881075658757
# 1   2022-03-09 12:58:22+00:00  1501542912345075714
# 2   2022-03-09 10:58:34+00:00  1501512762727755776
# 3   2022-03-09 05:19:40+00:00  1501427477201453056
# 4   2022-03-08 12:10:49+00:00  1501168558201470982
# ..                        ...                  ...
# 96  2022-03-04 11:33:57+00:00  1499709728905056256
# 97  2022-03-04 11:30:42+00:00  1499708912173412358
# 98  2022-03-04 11:14:43+00:00  1499704890762747908
# 99  2022-03-04 10:16:54+00:00  1499690340126658568
# 100 2022-03-04 08:27:21+00:00  1499662769976606723
#
#                                                   Text         Username
# 0    नारी सशक्तिकरण की अप्रतिम प्रतीक, महान समाज सु...  myogiadityanath
# 1    असम नगर निकाय चुनाव में @BJP4Assam को मिली प्र...  myogiadityanath
# 2    ये खिलखिलाहट, ये निश्छल स्नेह, ये निश्चिंतता औ...  myogiadityanath
# 3    यूक्रेन से सुरक्षित घर वापस आए विद्यार्थियों क...  myogiadityanath
# 4    याद रखना!\n\nकभी भी शॉर्टकट का रास्ता व्यक्ति ...  myogiadityanath
# ..                                                 ...              ...
# 96   ये जो घोर परिवारवादी हैं, इनका इतिहास एक-एक पन...  myogiadityanath
# 97   इस बार आपका वोट 'समर्थ भारत के लिए सशक्त उत्तर...  myogiadityanath
# 98   जौनपुर के जफराबाद विधान सभा क्षेत्र में आयोजित...  myogiadityanath
# 99   मुंगरा बादशाहपुर, जनपद जौनपुर में जनता-जनार्दन...  myogiadityanath
# 100  जनपद मिर्जापुर में आदरणीय प्रधानमंत्री श्री @n...  myogiadityanath
#
# [101 rows x 4 columns]

# %%
# doing Something Something

# %%
# bjp_candidates=[]
# sp_candidates=[]
# inc_candidates=[]
# aap_candidates=[]
# other_candidates=[]
